# %% [markdown]
# ## Netflix Analysis

# %% [markdown]
# in this project we are going to analyse the netfilx data

# %% [markdown]
# ## About the dataset

# %% [markdown]
# In this dataset we have 100 years of data with diff columns like type,title,director,rating etc

# %% [markdown]
# ## Library Requirements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Loading the data

# %%
df=pd.read_csv('./netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ## Preprocessing the data

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# #### Datatype of All Columns

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# #### Null Value of All Columns

# %%
pd.isnull(df).sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.size
# Out:
# 105684

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### to serch particular title is available in this dataset or not so use isin() function

# %%
df[df['title'].isin(['Kota Factory'])]
# Out:
#   show_id     type         title director
# 4      s5  TV Show  Kota Factory      NaN  \
#
#                                                 cast country
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India  \
#
#            date_added  release_year rating   duration
# 4  September 24, 2021          2021  TV-MA  2 Seasons  \
#
#                                            listed_in
# 4  International TV Shows, Romantic TV Shows, TV ...  \
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# #### Only India

# %%
df[df['country']=='India']
# Out:
#      show_id     type                          title                 director
# 4         s5  TV Show                   Kota Factory                      NaN  \
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
#                                                    cast country
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39    Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50    Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                  NaN   India
# ...                                                 ...     ...
# 8773  Ankush Choudhary, Smita Shewale, Mohan Joshi, ...   India
# 8775  Vishesh Bansal, Mona Singh, Akarsh Khurana, Ah...   India
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...   India
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...   India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added release_year rating   duration
# 4     September 24, 2021   2021-01-01  TV-MA  2 Seasons  \
# 24    September 21, 2021   1998-01-01  TV-14    166 min
# 39    September 16, 2021   2021-01-01  TV-Y7  3 Seasons
# 50    September 15, 2021   2014-01-01  TV-PG   1 Season
# 66    September 15, 2021   2014-01-01   TV-G   1 Season
# ...                  ...          ...    ...        ...
# 8773     January 1, 2018   2006-01-01  TV-PG    151 min
# 8775     August 31, 2018   2018-01-01  TV-PG   1 Season
# 8798   December 31, 2019   2014-01-01  TV-MA    131 min
# 8799   February 15, 2018   2009-01-01  TV-14    120 min
# 8806       March 2, 2019   2015-01-01  TV-14    111 min
#
#                                               listed_in
# 4     International TV Shows, Romantic TV Shows, TV ...  \
# 24      Comedies, International Movies, Romantic Movies
# 39                                             Kids' TV
# 50    International TV Shows, TV Dramas, TV Sci-Fi &...
# 66                   Docuseries, International TV Shows
# ...                                                 ...
# 8773             Comedies, Dramas, International Movies
# 8775                International TV Shows, TV Comedies
# 8798             Comedies, Dramas, International Movies
# 8799                       Dramas, International Movies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description  year
# 4     In a city of coaching centers known to train I...  2021
# 24    When the father of the man she loves insists t...  1998
# 39    A brave, energetic little boy with superhuman ...  2021
# 50    After the ancient Great War, the god Chitragup...  2014
# 66    Explore the history and flavors of regional In...  2014
# ...                                                 ...   ...
# 8773  Thanks to an arranged marriage that was design...  2006
# 8775  In the summer of 1998, middle child Harshu bal...  2018
# 8798  A philandering small-town mechanic's political...  2014
# 8799  A change in the leadership of a political part...  2009
# 8806  A scrappy but poor boy worms his way into a ty...  2015
#
# [972 rows x 13 columns]

# %% [markdown]
# ##### Aishwarya Rai Bachchan movie or tv shows

# %%
new_df=df.fillna("abc")
new_df[new_df['cast'].str.contains('Aishwarya Rai Bachchan')]
# Out:
#      show_id   type                      title               director
# 24       s25  Movie                      Jeans             S. Shankar  \
# 2544   s2545  Movie             Action Replayy    Vipul Amrutlal Shah
# 3917   s3918  Movie                      Shabd            Leena Yadav
# 4573   s4574  Movie               Jodhaa Akbar     Ashutosh Gowariker
# 4724   s4725  Movie                  Guzaarish  Sanjay Leela Bhansali
# 5008   s5009  Movie                       Guru            Mani Ratnam
# 6912   s6913  Movie  Hamara Dil Aapke Paas Hai         Satish Kaushik
# 7249   s7250  Movie           Kyun! Ho Gaya Na           Samir Karnik
# 8144   s8145  Movie                       Taal           Subhash Ghai
#
#                                                    cast country
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India  \
# 2544  Akshay Kumar, Aishwarya Rai Bachchan, Om Puri,...   India
# 3917  Sanjay Dutt, Aishwarya Rai Bachchan, Zayed Kha...   India
# 4573  Hrithik Roshan, Aishwarya Rai Bachchan, Sonu S...   India
# 4724  Hrithik Roshan, Aishwarya Rai Bachchan, Sherna...   India
# 5008  Abhishek Bachchan, Mithun Chakraborty, Aishwar...   India
# 6912  Anil Kapoor, Aishwarya Rai Bachchan, Sonali Be...   India
# 7249  Aishwarya Rai Bachchan, Vivek Oberoi, Amitabh ...   India
# 8144  Anil Kapoor, Aishwarya Rai Bachchan, Akshaye K...   India
#
#               date_added  release_year rating duration
# 24    September 21, 2021          1998  TV-14  166 min  \
# 2544        May 11, 2020          2010  TV-PG  129 min
# 3917      April 15, 2019          2005  TV-14  146 min
# 4573     October 1, 2018          2008  TV-14  214 min
# 4724      August 2, 2018          2010  TV-14  121 min
# 5008       March 1, 2018          2007  TV-PG  155 min
# 6912       March 1, 2018          2000  TV-14  158 min
# 7249       March 1, 2018          2004  TV-PG  165 min
# 8144       March 1, 2018          1999  TV-PG  177 min
#
#                                               listed_in
# 24      Comedies, International Movies, Romantic Movies  \
# 2544  Children & Family Movies, Comedies, Internatio...
# 3917      Dramas, International Movies, Romantic Movies
# 4573   Action & Adventure, Dramas, International Movies
# 4724                       Dramas, International Movies
# 5008                       Dramas, International Movies
# 6912     Dramas, International Movies, Music & Musicals
# 7249              International Movies, Romantic Movies
# 8144     Dramas, International Movies, Music & Musicals
#
#                                             description
# 24    When the father of the man she loves insists t...
# 2544  Sick of his parents’ constant squabbling, a yo...
# 3917  When a novelist seeks inspiration by urging hi...
# 4573  In 16th-century India, what begins as a strate...
# 4724  After an onstage disaster leaves an illusionis...
# 5008  Ambitious Gurukant Desai ignores his father's ...
# 6912  Love blooms when kind-hearted Avinash takes in...
# 7249  Cinematic lovebirds Aishwarya Rai and Vivek Ob...
# 8144  Businessman Manav falls for aspiring singer Ma...

# %% [markdown]
# #### Unique Rating

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Count of Unique Rating

# %%
df['rating'].nunique()
# Out:
# 17

# %% [markdown]
# #### how many movie has pg rating and it is from india

# %%
df[(df['rating']=='PG') & (df['country']=='India') & (df['type']=="Movie")]
# Out:
#      show_id   type             title          director
# 1022   s1023  Movie  Taare Zameen Par        Aamir Khan  \
# 4466   s4467  Movie          Zokkomon  Satyajit Bhatkal
#
#                                                    cast country
# 1022  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...   India  \
# 4466  Darsheel Safary, Anupam Kher, Manjari Fadnis, ...   India
#
#             date_added  release_year rating duration
# 1022    April 17, 2021          2007     PG  162 min  \
# 4466  November 1, 2018          2011     PG  104 min
#
#                              listed_in
# 1022      Dramas, International Movies  \
# 4466  Children & Family Movies, Dramas
#
#                                             description
# 1022  When daydreamer Ishaan is sent to boarding sch...
# 4466  When his cruel uncle abandons him, a young orp...

# %% [markdown]
# ##### Convert Year Columns datatype to datetime

# %%
df['release_year']=pd.to_datetime(df['release_year'], format='%Y')

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year    datetime64[ns]
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %% [markdown]
# #### Create New Column

# %%
df['year']=df['release_year'].dt.year

# %% [markdown]
# #### show all tvshows or movies with specific year

# %%
df[(df['type']=='Movie') & (df['year']==2018)]
# Out:
#      show_id   type                                              title
# 73       s74  Movie                                       King of Boys  \
# 94       s95  Movie                                          Show Dogs
# 96       s97  Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 107     s108  Movie                                   A Champion Heart
# 157     s158  Movie                                           Level 16
# ...      ...    ...                                                ...
# 8706   s8707  Movie                                     We the Animals
# 8724   s8725  Movie                                 What Still Remains
# 8732   s8733  Movie                                      White Chamber
# 8743   s8744  Movie                                           Wildlife
# 8774   s8775  Movie                                          يوم الدين
#
#                 director                                               cast
# 73          Kemi Adetiba  Sola Sobowale, Adesua Etomi, Remilekun "Remini...  \
# 94          Raja Gosnell  Will Arnett, Ludacris, Natasha Lyonne, Stanley...
# 96         Stephen Kijak  Ronnie Van Zandt, Gary Rossington, Allen Colli...
# 107         David de Vos  Mandy Grace, David de Vos, Donna Rusch, Devan ...
# 157   Danishka Esterhazy  Katie Douglas, Celina Martin, Peter Outerbridg...
# ...                  ...                                                ...
# 8706      Jeremiah Zagar  Evan Rosado, Josiah Gabriel, Isaiah Kristian, ...
# 8724        Josh Mendoza  Lulu Antariksa, Colin O'Donoghue, Mimi Rogers,...
# 8732        Paul Raschid  Shauna MacDonald, Oded Fehr, Amrita Acharia, S...
# 8743           Paul Dano  Carey Mulligan, Ed Oxenbould, Bill Camp, Jake ...
# 8774     Abu Bakr Shawky  Rady Gamal, Ahmed Abdelhafiz, Shahira Fahmy, S...
#
#                             country          date_added release_year rating
# 73                          Nigeria  September 14, 2021   2018-01-01  TV-MA  \
# 94    United Kingdom, United States   September 8, 2021   2018-01-01     PG
# 96                    United States   September 7, 2021   2018-01-01  TV-MA
# 107                   United States   September 4, 2021   2018-01-01      G
# 157                          Canada   September 1, 2021   2018-01-01  TV-14
# ...                             ...                 ...          ...    ...
# 8706                  United States   February 11, 2019   2018-01-01      R
# 8724                  United States   December 21, 2018   2018-01-01  TV-14
# 8732                 United Kingdom      August 1, 2019   2018-01-01  TV-MA
# 8743                  United States   September 1, 2020   2018-01-01  PG-13
# 8774  Egypt, Austria, United States    October 22, 2019   2018-01-01  TV-14
#
#      duration                                         listed_in
# 73    182 min                      Dramas, International Movies  \
# 94     90 min                Children & Family Movies, Comedies
# 96     97 min                   Documentaries, Music & Musicals
# 107    90 min                  Children & Family Movies, Dramas
# 157   102 min                       Sci-Fi & Fantasy, Thrillers
# ...       ...                                               ...
# 8706   93 min                        Dramas, Independent Movies
# 8724   91 min                                 Dramas, Thrillers
# 8732   89 min                       Sci-Fi & Fantasy, Thrillers
# 8743  105 min                        Dramas, Independent Movies
# 8774   97 min  Dramas, Independent Movies, International Movies
#
#                                             description  year
# 73    When a powerful businesswoman’s political ambi...  2018
# 94    A rough and tough police dog must go undercove...  2018
# 96    Using interviews and archival footage, this do...  2018
# 107   When a grieving teen must work off her debt to...  2018
# 157   In a bleak academy that teaches girls the virt...  2018
# ...                                                 ...   ...
# 8706  A trio of brothers cope with their parents' vo...  2018
# 8724  Struggling to survive alone post-apocalypse, a...  2018
# 8732  When a civil war ravages the UK, a scientist a...  2018
# 8743  A teen’s life in 1960 Montana grows complicate...  2018
# 8774  A man cured of leprosy and a young orphan leav...  2018
#
# [767 rows x 13 columns]

# %% [markdown]
# #### G rating tv_shows in year 2018

# %%
df[(df['rating']=='G') & (df['year']==2018) & (df['type']=='Movie')]
# Out:
#      show_id   type                 title      director
# 107     s108  Movie      A Champion Heart  David de Vos  \
# 4873   s4874  Movie  Pup Star: World Tour  Robert Vince
#
#                                                    cast
# 107   Mandy Grace, David de Vos, Donna Rusch, Devan ...  \
# 4873  Jed Ress, Makenzie Moss, Denisse Ojeda, Reggie...
#
#                            country         date_added release_year rating
# 107                  United States  September 4, 2021   2018-01-01      G  \
# 4873  Canada, Japan, United States        May 5, 2018   2018-01-01      G
#
#      duration                                          listed_in
# 107    90 min                   Children & Family Movies, Dramas  \
# 4873   87 min  Children & Family Movies, Comedies, Music & Mu...
#
#                                             description  year
# 107   When a grieving teen must work off her debt to...  2018
# 4873  Talented pooches from around the world compete...  2018

# %% [markdown]
# ##### latest Movie or tvshow

# %%
df.sort_values(by='year',ascending=False)
# Out:
#      show_id     type                                          title
# 693     s694    Movie                         Ali & Ratu Ratu Queens  \
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast
# 693   Lucky Kuswandi  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...  \
# 781    Peter Galison                                                NaN
# 762    Lee Kae-byeok          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung
# 763              NaN  Nonso Anozie, Christian Convery, Adeel Akhtar,...
# 764    Jayan Moodley  Jailoshini Naidoo, Maeshni Naicker, Madhushan ...
# ...              ...                                                ...
# 8660       John Ford                                                NaN
# 8763     John Huston                                                NaN
# 8205       John Ford                          Henry Fonda, Jane Darwell
# 7790     Frank Capra                                                NaN
# 4250             NaN                                                NaN
#
#             country         date_added release_year rating  duration
# 693             NaN      June 17, 2021   2021-01-01  TV-14   101 min  \
# 781             NaN       June 2, 2021   2021-01-01  TV-14    99 min
# 762     South Korea       June 4, 2021   2021-01-01  TV-14   103 min
# 763   United States       June 4, 2021   2021-01-01  TV-14  1 Season
# 764    South Africa       June 4, 2021   2021-01-01  TV-14    94 min
# ...             ...                ...          ...    ...       ...
# 8660  United States     March 31, 2017   1943-01-01  TV-PG    61 min
# 8763  United States     March 31, 2017   1943-01-01  TV-PG    45 min
# 8205  United States     March 31, 2017   1942-01-01  TV-14    18 min
# 7790  United States     March 31, 2017   1942-01-01  TV-14    52 min
# 4250            NaN  December 30, 2018   1925-01-01  TV-14  1 Season
#
#                                               listed_in
# 693              Comedies, Dramas, International Movies  \
# 781                                       Documentaries
# 762     Comedies, International Movies, Romantic Movies
# 763   TV Action & Adventure, TV Dramas, TV Sci-Fi & ...
# 764     Comedies, International Movies, Romantic Movies
# ...                                                 ...
# 8660                      Classic Movies, Documentaries
# 8763                                      Documentaries
# 8205                      Classic Movies, Documentaries
# 7790                      Classic Movies, Documentaries
# 4250                                           TV Shows
#
#                                             description  year
# 693   After his father's passing, a teenager sets ou...  2021
# 781   Follow scientists on their quest to understand...  2021
# 762   Faced with real-world opportunities and challe...  2021
# 763   On a perilous adventure across a post-apocalyp...  2021
# 764   To rekindle their marriages, best friends-turn...  2021
# ...                                                 ...   ...
# 8660  This World War II-era training film dramatizes...  1943
# 8763  Filmmaker John Huston narrates this Oscar-nomi...  1943
# 8205  Director John Ford captures combat footage of ...  1942
# 7790  Frank Capra's documentary chronicles the rise ...  1942
# 4250  This collection restores films from women who ...  1925
#
# [8807 rows x 13 columns]

# %% [markdown]
# #### How many Movies are listed in the "International Movies" category?

# %%
df[df['listed_in'].str.contains('International Movies')]
# Out:
#      show_id   type                                              title
# 7         s8  Movie                                            Sankofa  \
# 12       s13  Movie                                       Je Suis Karl
# 16       s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 22       s23  Movie                                    Avvai Shanmughi
# 24       s25  Movie                                              Jeans
# ...      ...    ...                                                ...
# 8794   s8795  Movie                                             اشتباك
# 8798   s8799  Movie                                           Zed Plus
# 8799   s8800  Movie                                              Zenda
# 8801   s8802  Movie                                            Zinzana
# 8806   s8807  Movie                                             Zubaan
#
#                                            director
# 7                                      Haile Gerima  \
# 12                              Christian Schwochow
# 16    Pedro de Echave García, Pablo Azorín Williams
# 22                                   K.S. Ravikumar
# 24                                       S. Shankar
# ...                                             ...
# 8794                                   Mohamed Diab
# 8798                        Chandra Prakash Dwivedi
# 8799                                 Avadhoot Gupte
# 8801                                Majid Al Ansari
# 8806                                    Mozez Singh
#
#                                                    cast
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...  \
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 16                                                  NaN
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8794  Nelly Karim, Hany Adel, Tarek Abdel Aziz, Ahme...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country          date_added
# 7     United States, Ghana, Burkina Faso, United Kin...  September 24, 2021  \
# 12                              Germany, Czech Republic  September 23, 2021
# 16                                                  NaN  September 22, 2021
# 22                                                  NaN  September 21, 2021
# 24                                                India  September 21, 2021
# ...                                                 ...                 ...
# 8794                                      Egypt, France    October 11, 2018
# 8798                                              India   December 31, 2019
# 8799                                              India   February 15, 2018
# 8801                       United Arab Emirates, Jordan       March 9, 2016
# 8806                                              India       March 2, 2019
#
#      release_year rating duration
# 7      1993-01-01  TV-MA  125 min  \
# 12     2021-01-01  TV-MA  127 min
# 16     2020-01-01  TV-MA   67 min
# 22     1996-01-01  TV-PG  161 min
# 24     1998-01-01  TV-14  166 min
# ...           ...    ...      ...
# 8794   2016-01-01  TV-14   98 min
# 8798   2014-01-01  TV-MA  131 min
# 8799   2009-01-01  TV-14  120 min
# 8801   2015-01-01  TV-MA   96 min
# 8806   2015-01-01  TV-14  111 min
#
#                                              listed_in
# 7     Dramas, Independent Movies, International Movies  \
# 12                        Dramas, International Movies
# 16                 Documentaries, International Movies
# 22                      Comedies, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8794  Dramas, Independent Movies, International Movies
# 8798            Comedies, Dramas, International Movies
# 8799                      Dramas, International Movies
# 8801           Dramas, International Movies, Thrillers
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  year
# 7     On a photo shoot in Ghana, an American model s...  1993
# 12    After most of her family is murdered in a terr...  2021
# 16    Declassified documents reveal the post-WWII li...  2020
# 22    Newly divorced and denied visitation rights wi...  1996
# 24    When the father of the man she loves insists t...  1998
# ...                                                 ...   ...
# 8794  Amid the tumult following Egyptian President M...  2016
# 8798  A philandering small-town mechanic's political...  2014
# 8799  A change in the leadership of a political part...  2009
# 8801  Recovering alcoholic Talal wakes up inside a s...  2015
# 8806  A scrappy but poor boy worms his way into a ty...  2015
#
# [2752 rows x 13 columns]

# %% [markdown]
# ## Visulization Of Data

# %% [markdown]
# ##### in which year highest number of movies or tv_shows was released

# %%
df['release_year'].dt.year.value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
grouped_data=df.groupby('year')['year'].count()
plt.figure(figsize=(14,7))
plt.plot(grouped_data.index,grouped_data.values,c='green')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.title('Number of Releases by Year')
plt.xticks(range(min(grouped_data.index), max(grouped_data.index)+5, 10))
plt.show()

# %% [markdown]
# #### Top 10 Years

# %%
grouped_data=df['release_year'].dt.year.value_counts().sort_values(ascending=False)[:10]
plt.figure(figsize = (10, 5))
plt.bar(grouped_data.index,grouped_data.values,color ='maroon',width=0.4)
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(grouped_data.index)
plt.title('Top 10 Count Of Movies Or Tv_Shows Based On Years')
plt.show()

# %% [markdown]
# ##### how many movies or tvshows

# %%
grouped_data=df.groupby('type')['type'].count()
grouped_data
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
grouped_data=df.groupby('type')['type'].count()
mycolors = ["blue", "green"]
plt.pie(grouped_data.values,labels=grouped_data.index,autopct='%1.2f%%',shadow=True,colors=mycolors)
plt.title('Count Of Movies And TV Shows') 
plt.legend()
plt.show()

# %% [markdown]
# ##### Top 10 Country

# %%
grouped_data = df.groupby('country')['country'].count().sort_values(ascending=False)[:10]
labels = grouped_data.index
sizes = grouped_data.values.tolist()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax.axis('equal')
ax.legend(title="Countries", loc='best')
plt.title('Top 10 Countries')
plt.show()

# %% [markdown]
# #### Top 10 Country Based On Movies

# %%
df_movies=df[df['type']=='Movie']
plt.figure(figsize = (10, 5))
grouped_data=df_movies.groupby('country')['country'].count().sort_values(ascending=False)[:10]
plt.bar(grouped_data.index,grouped_data.values,color='green',width=0.4)
plt.xlabel('Country')
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.title("Top 10 Country Based on Movies")
plt.show()

# %% [markdown]
# #### Distribution Of Movie by Rating

# %%
df_movies=df[df['type']=='Movie']
plt.figure(figsize = (10, 5))
grouped_data=df.groupby('rating')['rating'].count().sort_values(ascending=False)[:14]
plt.bar(grouped_data.index,grouped_data.values,color='lime',width=0.4)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Distribution of Ratings')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### top 10 Country Based On TV_Show

# %%
df_tv=df[df['type']=='TV Show']
plt.figure(figsize = (10, 5))
grouped_data=df_tv.groupby('country')['country'].count().sort_values(ascending=False)[:10]
plt.bar(grouped_data.index,grouped_data.values,color='red',width=0.4)
plt.xlabel('Country')
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.title("Top 10 Country Based On Tv_Show")
plt.show()

# %% [markdown]
# #### Distribution Of TV_Shows by Rating

# %%
df_tv=df[df['type']=='TV Show']
plt.figure(figsize = (10, 5))
grouped_data=df_tv.groupby('rating')['rating'].count().sort_values(ascending=False)
plt.bar(grouped_data.index,grouped_data.values,color='orange',width=0.4)
plt.xlabel('Country')
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.title("Top 10 Country Based on TV_Shows")
plt.show()

# %% [markdown]
# #### Visulization For India

# %%
Ind=df[df['country']=='India']
Ind.head(5)
# Out:
#    show_id     type                          title    director
# 4       s5  TV Show                   Kota Factory         NaN  \
# 24     s25    Movie                          Jeans  S. Shankar
# 39     s40  TV Show                   Chhota Bheem         NaN
# 50     s51  TV Show                  Dharmakshetra         NaN
# 66     s67  TV Show  Raja Rasoi Aur Anya Kahaniyan         NaN
#
#                                                  cast country
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India  \
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
# 50  Kashmira Irani, Chandan Anand, Dinesh Mehta, A...   India
# 66                                                NaN   India
#
#             date_added release_year rating   duration
# 4   September 24, 2021   2021-01-01  TV-MA  2 Seasons  \
# 24  September 21, 2021   1998-01-01  TV-14    166 min
# 39  September 16, 2021   2021-01-01  TV-Y7  3 Seasons
# 50  September 15, 2021   2014-01-01  TV-PG   1 Season
# 66  September 15, 2021   2014-01-01   TV-G   1 Season
#
#                                             listed_in
# 4   International TV Shows, Romantic TV Shows, TV ...  \
# 24    Comedies, International Movies, Romantic Movies
# 39                                           Kids' TV
# 50  International TV Shows, TV Dramas, TV Sci-Fi &...
# 66                 Docuseries, International TV Shows
#
#                                           description  year  movies
# 4   In a city of coaching centers known to train I...  2021   False
# 24  When the father of the man she loves insists t...  1998    True
# 39  A brave, energetic little boy with superhuman ...  2021   False
# 50  After the ancient Great War, the god Chitragup...  2014   False
# 66  Explore the history and flavors of regional In...  2014   False

# %%
grouped_data=Ind.groupby('type')['type'].count()
mycolors = ["Red", "Purple"]
plt.pie(grouped_data.values,labels=grouped_data.index,autopct='%1.2f%%',shadow=True,colors=mycolors)
plt.title('Count Of Movies And TV Shows In India') 
plt.legend()
plt.show()

# %% [markdown]
# #### Visulization For Usa

# %%
usa=df[df['country']=='United States']
grouped_data=usa.groupby('type')['type'].count()
mycolors = ["violet", "yellow"]
plt.pie(grouped_data.values,labels=grouped_data.index,autopct='%1.2f%%',shadow=True,colors=mycolors)
plt.title('Count Of Movies And TV Shows In USA') 
plt.legend()
plt.show()

# %% [markdown]
# #### Top 10 Director

# %%
grouped_data=df.groupby('director')['director'].count().sort_values(ascending=False)[:10]
labels = grouped_data.index
sizes = grouped_data.values.tolist()
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True)
ax.axis('equal')
#ax.legend(title="Director", loc='best')
plt.title('Top 10 Directors')
plt.show()

# %% [markdown]
# #### Movies And Tv_Shows in Diff Years

# %%
movies=df[df['type']=='Movie']
movies.head(5)
# Out:
#    show_id   type                             title
# 0       s1  Movie              Dick Johnson Is Dead  \
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director
# 0                 Kirsten Johnson  \
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast
# 0                                                 NaN  \
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added
# 0                                       United States  September 25, 2021  \
# 6                                                 NaN  September 24, 2021
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 9                                       United States  September 24, 2021
# 12                            Germany, Czech Republic  September 23, 2021
#
#    release_year rating duration
# 0    2020-01-01  PG-13   90 min  \
# 6    2021-01-01     PG   91 min
# 7    1993-01-01  TV-MA  125 min
# 9    2021-01-01  PG-13  104 min
# 12   2021-01-01  TV-MA  127 min
#
#                                            listed_in
# 0                                      Documentaries  \
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 9                                   Comedies, Dramas
# 12                      Dramas, International Movies
#
#                                           description  year  movies
# 0   As her father nears the end of his life, filmm...  2020    True
# 6   Equestria's divided. But a bright-eyed hero be...  2021    True
# 7   On a photo shoot in Ghana, an American model s...  1993    True
# 9   A woman adjusting to life after a loss contend...  2021    True
# 12  After most of her family is murdered in a terr...  2021    True

# %%
TV_Shows=df[df['type']=='TV Show']
TV_Shows.head(5)
# Out:
#   show_id     type                  title         director
# 1      s2  TV Show          Blood & Water              NaN  \
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added release_year rating   duration
# 1  September 24, 2021   2021-01-01  TV-MA  2 Seasons  \
# 2  September 24, 2021   2021-01-01  TV-MA   1 Season
# 3  September 24, 2021   2021-01-01  TV-MA   1 Season
# 4  September 24, 2021   2021-01-01  TV-MA  2 Seasons
# 5  September 24, 2021   2021-01-01  TV-MA   1 Season
#
#                                            listed_in
# 1    International TV Shows, TV Dramas, TV Mysteries  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year  movies
# 1  After crossing paths at a party, a Cape Town t...  2021   False
# 2  To protect his family from a powerful drug lor...  2021   False
# 3  Feuds, flirtations and toilet talk go down amo...  2021   False
# 4  In a city of coaching centers known to train I...  2021   False
# 5  The arrival of a charismatic young priest brin...  2021   False

# %%
g1=movies.groupby('year')['year'].count()
g1
# Out:
# year
# 1942      2
# 1943      3
# 1944      3
# 1945      3
# 1946      1
#        ...
# 2017    767
# 2018    767
# 2019    633
# 2020    517
# 2021    277
# Name: year, Length: 73, dtype: int64

# %%
g2=TV_Shows.groupby('year')['year'].count()
g2
# Out:
# year
# 1925      1
# 1945      1
# 1946      1
# 1963      1
# 1967      1
# 1972      1
# 1974      1
# 1977      1
# 1979      1
# 1981      1
# 1985      1
# 1986      2
# 1988      2
# 1989      1
# 1990      3
# 1991      1
# 1992      3
# 1993      4
# 1994      2
# 1995      2
# 1996      3
# 1997      4
# 1998      4
# 1999      7
# 2000      4
# 2001      5
# 2002      7
# 2003     10
# 2004      9
# 2005     13
# 2006     14
# 2007     14
# 2008     23
# 2009     34
# 2010     40
# 2011     40
# 2012     64
# 2013     63
# 2014     88
# 2015    162
# 2016    244
# 2017    265
# 2018    380
# 2019    397
# 2020    436
# 2021    315
# Name: year, dtype: int64

# %%
plt.figure(figsize=(14,7))
plt.plot(g1.index, g1.values, label='Movies',color='green')
plt.plot(g2.index, g2.values, label='TV_Shows',color='red')
plt.xlabel('Year')
plt.ylabel('Number of Releases')
plt.title('Number of Releases by Year')
plt.xticks(range(min(g1.index), max(g1.index)+5, 10))
plt.legend()
plt.show()

# %% [markdown]
# #### Month And Year Wise Release Using Heatmap

# %%
newdf=df

# %%
newdf['date_added'] = pd.to_datetime(newdf['date_added'], format='mixed', dayfirst=True)
newdf.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration
# 0 2021-09-25          2020  PG-13     90 min  \
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description       y    m
# 0  As her father nears the end of his life, filmm...  2021.0  9.0
# 1  After crossing paths at a party, a Cape Town t...  2021.0  9.0
# 2  To protect his family from a powerful drug lor...  2021.0  9.0
# 3  Feuds, flirtations and toilet talk go down amo...  2021.0  9.0
# 4  In a city of coaching centers known to train I...  2021.0  9.0

# %%
newdf['m'] = newdf['date_added'].dt.month

# %%
newdf['y']=newdf['date_added'].dt.year

# %%
newdf.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration
# 0 2021-09-25          2020  PG-13     90 min  \
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description       y    m
# 0  As her father nears the end of his life, filmm...  2021.0  9.0
# 1  After crossing paths at a party, a Cape Town t...  2021.0  9.0
# 2  To protect his family from a powerful drug lor...  2021.0  9.0
# 3  Feuds, flirtations and toilet talk go down amo...  2021.0  9.0
# 4  In a city of coaching centers known to train I...  2021.0  9.0

# %%
newdf=newdf.dropna()

# %%
newdf['y']=newdf['y'].astype(int)
newdf['m']=newdf['m'].astype(int)
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_9320\2334685133.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['y']=newdf['y'].astype(int)
# C:\Users\yash\AppData\Local\Temp\ipykernel_9320\2334685133.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['m']=newdf['m'].astype(int)

# %%
newdf
# Out:
#      show_id     type                          title             director
# 7         s8    Movie                        Sankofa         Haile Gerima  \
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...  \
# 8     Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...                                                 ...
# 8801  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24  \
# 8                                        United Kingdom 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# 24                                                India 2021-09-21
# ...                                                 ...        ...
# 8801                       United Arab Emirates, Jordan 2016-03-09
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating   duration
# 7             1993  TV-MA    125 min  \
# 8             2021  TV-14  9 Seasons
# 9             2021  PG-13    104 min
# 12            2021  TV-MA    127 min
# 24            1998  TV-14    166 min
# ...            ...    ...        ...
# 8801          2015  TV-MA     96 min
# 8802          2007      R    158 min
# 8804          2009      R     88 min
# 8805          2006     PG     88 min
# 8806          2015  TV-14    111 min
#
#                                              listed_in
# 7     Dramas, Independent Movies, International Movies  \
# 8                         British TV Shows, Reality TV
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# 24     Comedies, International Movies, Romantic Movies
# ...                                                ...
# 8801           Dramas, International Movies, Thrillers
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description     y   m
# 7     On a photo shoot in Ghana, an American model s...  2021   9
# 8     A talented batch of amateur bakers face off in...  2021   9
# 9     A woman adjusting to life after a loss contend...  2021   9
# 12    After most of her family is murdered in a terr...  2021   9
# 24    When the father of the man she loves insists t...  2021   9
# ...                                                 ...   ...  ..
# 8801  Recovering alcoholic Talal wakes up inside a s...  2016   3
# 8802  A political cartoonist, a crime reporter and a...  2019  11
# 8804  Looking to survive in a world taken over by zo...  2019  11
# 8805  Dragged from civilian life, a former superhero...  2020   1
# 8806  A scrappy but poor boy worms his way into a ty...  2019   3
#
# [5332 rows x 14 columns]

# %%
heatmap_data = newdf.pivot_table(index='m', columns='y', aggfunc='size')
plt.figure(figsize=(10, 6))  
sns.heatmap(heatmap_data,cmap='YlOrRd')
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Heat Map of Month and Year')
plt.show()
